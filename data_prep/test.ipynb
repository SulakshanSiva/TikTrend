# %% [markdown]
# Import Statements

# %%
import pandas as pd

# %% [markdown]
# Format dataset into a table

# %%
df = pd.read_csv("sug_users_vids_all.csv")
df
# Out:
#                         id  create_time        user_name  \
# 0      6892428462015958273   1604768557      john.cena10
# 1      6891790235336822018   1604619960      john.cena10
# 2      6891264678832475393   1604497592      john.cena10
# 3      6891050048403049730   1604447622      john.cena10
# 4      6890886086613126402   1604409445      john.cena10
# ...                    ...          ...              ...
# 41697  6886179281634905349   1603313593  victoriabachlet
# 41698  6885924542754114822   1603254315  victoriabachlet
# 41699  6885815006982671621   1603228764  victoriabachlet
# 41700  6885806757847895301   1603226846  victoriabachlet
# 41701  6885567759367884037   1603171287  victoriabachlet
#
#                                                 hashtags  \
# 0      ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1      ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2              ['johncena', 'love', 'fyp', 'foryoupage']
# ...

# %%
df = df.drop('create_time', axis=1)
df = df.drop('id', axis=1)
df = df.drop('song', axis=1)
df = df.drop('n_total_vids', axis=1)
df
# Out:
#              user_name                                           hashtags  \
# 0          john.cena10  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1          john.cena10  ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2          john.cena10          ['johncena', 'love', 'fyp', 'foryoupage']
# 3          john.cena10  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...
# 4          john.cena10         ['johncena', 'foryoupage', 'fyp', 'viral']
# ...                ...                                                ...
# 41697  victoriabachlet                                                 []
# 41698  victoriabachlet                                                 []
# 41699  victoriabachlet                                                 []
# 41700  victoriabachlet                                                 []
# 41701  victoriabachlet                                                 []
#
#        video_length  n_likes  n_shares  n_comments  n_plays  n_followers  \
# ...
