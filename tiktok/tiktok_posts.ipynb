# %% [markdown]
# # Processing TikTok Post Data

# %%
! pip install pandas
! pip install matplotlib

# %%
import pandas as pd
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
import ast
import numpy as np
from PIL import Image
import re

# %%
df = pd.read_csv('users_vids_short.csv')
# df = pd.read_csv('sug_users_vids1.csv')
# df = pd.read_csv('sug_users_vids_all.csv')

# %%
df.head()
# Out:
#                     id  create_time    user_name  \
# 0  6892428462015958273   1604768557  john.cena10
# 1  6891790235336822018   1604619960  john.cena10
# 2  6891264678832475393   1604497592  john.cena10
# 3  6891050048403049730   1604447622  john.cena10
# 4  6890886086613126402   1604409445  john.cena10
#
#                                             hashtags  \
# 0  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1  ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2          ['johncena', 'love', 'fyp', 'foryoupage']
# 3  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...
# 4         ['johncena', 'foryoupage', 'fyp', 'viral']
#
#                           song  video_length  n_likes  n_shares  n_comments  \
# 0                 الصوت الأصلي             8     1984         3          18
# 1                 الصوت الأصلي             6     7372         9          51
# 2  The Time Is Now (John Cena)             5     4623        11          27
# 3                 الصوت الأصلي             6     7931         6          24
# 4                 الصوت الأصلي            15     3229         9          14
#
#    n_plays  n_followers  n_total_likes  n_total_vids
# 0    12800      1000000        4700000           211
# 1    52800      1000000        4700000           211
# 2    37700      1000000        4700000           211
# 3    51200      1000000        4700000           211
# 4    24700      1000000        4700000           211

# %% [markdown]
# #### Remove Unnecessary Data

# %%
df.drop(['id', 'user_name', 'song'], axis=1, inplace=True)
# df.drop('user_name', axis=1, inplace=True)
# df.drop('song', axis=1, inplace=True)
# df.drop('create_time', axis=1, inplace=True)
df.head()
# Out:
#    create_time                                           hashtags  \
# 0   1604768557  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1   1604619960  ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2   1604497592          ['johncena', 'love', 'fyp', 'foryoupage']
# 3   1604447622  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...
# 4   1604409445         ['johncena', 'foryoupage', 'fyp', 'viral']
#
#    video_length  n_likes  n_shares  n_comments  n_plays  n_followers  \
# 0             8     1984         3          18    12800      1000000
# 1             6     7372         9          51    52800      1000000
# 2             5     4623        11          27    37700      1000000
# 3             6     7931         6          24    51200      1000000
# 4            15     3229         9          14    24700      1000000
#
#    n_total_likes  n_total_vids
# 0        4700000           211
# 1        4700000           211
# 2        4700000           211
# 3        4700000           211
# 4        4700000           211

# %% [markdown]
# ### Processing Time

# %%
df['datetime'] = pd.to_datetime(df['create_time'], unit='s')
df['year'] = df['datetime'].dt.year
df['month'] = df['datetime'].dt.month
df['day'] = df['datetime'].dt.day
df['weekday'] = df['datetime'].dt.weekday
df['hour'] = df['datetime'].dt.hour
df.head()
# Out:
#    create_time                                           hashtags  \
# 0   1604768557  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1   1604619960  ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2   1604497592          ['johncena', 'love', 'fyp', 'foryoupage']
# 3   1604447622  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...
# 4   1604409445         ['johncena', 'foryoupage', 'fyp', 'viral']
#
#    video_length  n_likes  n_shares  n_comments  n_plays  n_followers  \
# 0             8     1984         3          18    12800      1000000
# 1             6     7372         9          51    52800      1000000
# 2             5     4623        11          27    37700      1000000
# 3             6     7931         6          24    51200      1000000
# 4            15     3229         9          14    24700      1000000
#
#    n_total_likes  n_total_vids            datetime  year  month  day  weekday  \
# 0        4700000           211 2020-11-07 17:02:37  2020     11    7        5
# 1        4700000           211 2020-11-05 23:46:00  2020     11    5        3
# 2        4700000           211 2020-11-04 13:46:32  2020     11    4        2
# 3        4700000           211 2020-11-03 23:53:42  2020     11    3        1
# 4        4700000           211 2020-11-03 13:17:25  2020     11    3        1
#
#    hour
# 0    17
# 1    23
# 2    13
# 3    23
# 4    13

# %% [markdown]
# ##### Cyclical Encoding

# %%
#assume each month is approx 31 days
df['day_sin'] = np.sin(2 * np.pi * df['day'] / 31)
df['day_cos'] = np.cos(2 * np.pi * df['day'] / 31)

df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['weekday_sin'] = np.sin(2 * np.pi * df['weekday']/7)
df['weekday_cos'] = np.cos(2 * np.pi * df['weekday']/7)

df.head()
# Out:
#    create_time                                           hashtags  \
# 0   1604768557  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...
# 1   1604619960  ['johncena', 'love', 'tiktok', 'halloween', 'q...
# 2   1604497592          ['johncena', 'love', 'fyp', 'foryoupage']
# 3   1604447622  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...
# 4   1604409445         ['johncena', 'foryoupage', 'fyp', 'viral']
#
#    video_length  n_likes  n_shares  n_comments  n_plays  n_followers  \
# 0             8     1984         3          18    12800      1000000
# 1             6     7372         9          51    52800      1000000
# 2             5     4623        11          27    37700      1000000
# 3             6     7931         6          24    51200      1000000
# 4            15     3229         9          14    24700      1000000
#
#    n_total_likes  n_total_vids  ... weekday  hour   day_sin   day_cos  \
# 0        4700000           211  ...       5    17  0.988468  0.151428
# 1        4700000           211  ...       3    23  0.848644  0.528964
# 2        4700000           211  ...       2    13  0.724793  0.688967
# 3        4700000           211  ...       1    23  0.571268  0.820763
# 4        4700000           211  ...       1    13  0.571268  0.820763
#
#    month_sin  month_cos  hour_sin  hour_cos  weekday_sin  weekday_cos
# 0       -0.5   0.866025 -0.965926 -0.258819    -0.974928    -0.222521
# 1       -0.5   0.866025 -0.258819  0.965926     0.433884    -0.900969
# 2       -0.5   0.866025 -0.258819 -0.965926     0.974928    -0.222521
# 3       -0.5   0.866025 -0.258819  0.965926     0.781831     0.623490
# 4       -0.5   0.866025 -0.258819 -0.965926     0.781831     0.623490
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### Removing Unnecessary Time Data

# %%
df.drop(['weekday', 'hour', 'month', 'day', 'datetime', 'create_time'], axis=1, inplace=True)
df.head()
# Out:
#                                             hashtags  video_length  n_likes  \
# 0  ['johncena', 'love', 'tiktok', 'fyp', 'foryoup...             8     1984
# 1  ['johncena', 'love', 'tiktok', 'halloween', 'q...             6     7372
# 2          ['johncena', 'love', 'fyp', 'foryoupage']             5     4623
# 3  ['johncena', 'fyp', 'foryoupage', 'viral', 'co...             6     7931
# 4         ['johncena', 'foryoupage', 'fyp', 'viral']            15     3229
#
#    n_shares  n_comments  n_plays  n_followers  n_total_likes  n_total_vids  \
# 0         3          18    12800      1000000        4700000           211
# 1         9          51    52800      1000000        4700000           211
# 2        11          27    37700      1000000        4700000           211
# 3         6          24    51200      1000000        4700000           211
# 4         9          14    24700      1000000        4700000           211
#
#    year   day_sin   day_cos  month_sin  month_cos  hour_sin  hour_cos  \
# 0  2020  0.988468  0.151428       -0.5   0.866025 -0.965926 -0.258819
# 1  2020  0.848644  0.528964       -0.5   0.866025 -0.258819  0.965926
# 2  2020  0.724793  0.688967       -0.5   0.866025 -0.258819 -0.965926
# 3  2020  0.571268  0.820763       -0.5   0.866025 -0.258819  0.965926
# 4  2020  0.571268  0.820763       -0.5   0.866025 -0.258819 -0.965926
#
#    weekday_sin  weekday_cos
# 0    -0.974928    -0.222521
# 1     0.433884    -0.900969
# 2     0.974928    -0.222521
# 3     0.781831     0.623490
# 4     0.781831     0.623490

# %% [markdown]
# ### Processing Hashtags

# %% [markdown]
# #### Handle NaN Data

# %%
# Convert hashtags to string 
df['hashtags'] = df['hashtags'].apply(ast.literal_eval)
df['hashtags'] = df['hashtags'].apply(lambda x: x if x != [] else ["NoHashtag"])

print(df)
# Out:
#     create_time    user_name  \
# 0    1604768557  john.cena10
# 1    1604619960  john.cena10
# 2    1604497592  john.cena10
# 3    1604447622  john.cena10
# 4    1604409445  john.cena10
# ..          ...          ...
# 95   1596312708      mrbeast
# 96   1596056570      mrbeast
# 97   1595791388      mrbeast
# 98   1595353928      mrbeast
# 99   1595181506      mrbeast
#
#                                              hashtags  \
# 0    [johncena, love, tiktok, fyp, foryoupage, vibes]
# 1   [johncena, love, tiktok, halloween, queen, rob...
# 2                   [johncena, love, fyp, foryoupage]
# 3   [johncena, fyp, foryoupage, viral, comedy, cha...
# 4                  [johncena, foryoupage, fyp, viral]
# ..                                                ...
# 95                                        [NoHashtag]
# 96                                        [NoHashtag]
# 97                                        [NoHashtag]
# 98                                        [NoHashtag]
# 99                                        [NoHashtag]
#
#                            song  video_length  n_likes  n_shares  n_comments  \
# 0                  الصوت الأصلي             8     1984         3          18
# 1                  الصوت الأصلي             6     7372         9          51
# 2   The Time Is Now (John Cena)             5     4623        11          27
# 3                  الصوت الأصلي             6     7931         6          24
# 4                  الصوت الأصلي            15     3229         9          14
# ..                          ...           ...      ...       ...         ...
# 95               original sound             9   864000      1583        7781
# 96               original sound            18  1200000      1402        9295
# 97               original sound            18  1300000      1358       13600
# 98                     Trap Sax            10  2200000      3788       11600
# 99                    Only Time            15   489200       579        5115
#
#      n_plays  n_followers  n_total_likes  n_total_vids
# 0      12800      1000000        4700000           211
# 1      52800      1000000        4700000           211
# 2      37700      1000000        4700000           211
# 3      51200      1000000        4700000           211
# 4      24700      1000000        4700000           211
# ..       ...          ...            ...           ...
# 95   5200000     12600000      141000000           129
# 96   6500000     12600000      141000000           129
# 97   6500000     12600000      141000000           129
# 98  15600000     12600000      141000000           129
# 99   3000000     12600000      141000000           129
#
# [100 rows x 12 columns]

# %%
explodedDf = df['hashtags'].explode()

# %% [markdown]
# #### Remove Special Characters and Whitespace

# %%
def removeSpecialCharacters(hashtags):
    processedHashtag = [re.sub(r'[^a-zA-Z0-9]', '', hashtag) for hashtag in hashtags]
    return processedHashtag

# %%
df['hashtags'] = df['hashtags'].apply(removeSpecialCharacters)
df.head()
# Out:
#    create_time    user_name  \
# 0   1604768557  john.cena10
# 1   1604619960  john.cena10
# 2   1604497592  john.cena10
# 3   1604447622  john.cena10
# 4   1604409445  john.cena10
#
#                                             hashtags  \
# 0   [johncena, love, tiktok, fyp, foryoupage, vibes]
# 1  [johncena, love, tiktok, halloween, queen, rob...
# 2                  [johncena, love, fyp, foryoupage]
# 3  [johncena, fyp, foryoupage, viral, comedy, cha...
# 4                 [johncena, foryoupage, fyp, viral]
#
#                           song  video_length  n_likes  n_shares  n_comments  \
# 0                 الصوت الأصلي             8     1984         3          18
# 1                 الصوت الأصلي             6     7372         9          51
# 2  The Time Is Now (John Cena)             5     4623        11          27
# 3                 الصوت الأصلي             6     7931         6          24
# 4                 الصوت الأصلي            15     3229         9          14
#
#    n_plays  n_followers  n_total_likes  n_total_vids
# 0    12800      1000000        4700000           211
# 1    52800      1000000        4700000           211
# 2    37700      1000000        4700000           211
# 3    51200      1000000        4700000           211
# 4    24700      1000000        4700000           211

# %% [markdown]
# #### Handling Similar Hashtags

# %% [markdown]
# ####

# %% [markdown]
# #### Word to Vec
